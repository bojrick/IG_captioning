# %%
from data_helper import *
from Dataset import *
import matplotlib.pyplot as plt

# %%
data_path = 'd:\\IG Data\\'
file_dict = create_file_paths_dict(data_path)
#print(file_dict)
data_df = create_data_csv(file_dict)

# %%
transformer = transforms.Compose([
    transforms.Resize(255),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])
dataset_1 = IG_img_caption_dataset(csv_file = data_df,prof_type = 'natgeo',transform = None)

trainloader_1 = DataLoader(dataset=dataset_1,batch_size=5)

# %%
for sam in range(len(dataset_1)):
    sample = dataset_1[sam]
    plt.imshow(sample['image'])
    plt.show()
    print(sample['caption'])
    if sam == 5:
        break
# Out:
# ['greetings', 'friends', 'i', 'am', 'conradclimber', 'leader', 'of', 'the', '2012', 'national', 'geographic', 'everest', 'expedition', 'while', 'planning', 'our', 'expedition', 'i', 'suggested', 'we', 'post', 'on', 'instagram', 'the', 'style', 'that', 'we', 'all', 'share', 'in', 'the', 'moment', 'small', 'vignettes', 'of', 'life', 'with', 'a', 'few', 'filters', 'and', 'effects', 'just', 'for', 'fun', 'we', 'will', 'be', 'sharing', 'images', 'from', 'nepal', 'as', 'we', 'trek', 'to', 'basecamp', 'and', 'on', 'the', 'mountain', 'if', 'we', 'are', 'lucky', 'we', 'might', 'even', 'share', 'from', 'the', 'summit', 'thanks', 'natty', 'g', 'digital', 'for', 'trusting', 'us', 'with', 'this', 'unique', 'opportunity', 'please', 'follow', 'along', 'as', 'we', 'climb', 'our', 'planet', 'is', 'highest', 'peak', 'oneverest', 'this', 'first', 'image', 'is', 'of', 'ganesh', 'a', 'hindu', 'god', 'buddha', 'and', 'an', 'owl', 'a', 'wonderful', 'reminder', 'of', 'peaceful', 'co', 'existence']
# ['ohm', 'mani', 'padme', 'hum', 'the', 'jewel', 'is', 'in', 'the', 'heart', 'of', 'the', 'lotus', 'mani', 'stones', 'have', 'this', 'simple', 'prayer', 'carved', 'into', 'them', 'the', 'area', 'around', 'ghat', 'has', 'numerous', 'mani', 'walls', 'and', 'prayer', 'flags', 'for', 'the', 'sherpa', 'people', 'it', 'is', 'auspicious', 'to', 'pass', 'clockwise']
# ['sherpa', 'culture', 'one', 'of', 'the', 'kindest', 'and', 'most', 'textured', 'indigenous', 'mountain', 'cultures', 'in', 'the', 'world', 'the', 'khumbu', 'is', 'the', 'epicenter', 'of', 'their', 'living', 'heritage', 'hospitality', 'unmatched', 'it', 'feels', 'good', 'to', 'be', 'back']
# ['emilyaharrington', 'acclimatizing', 'outside', 'of', 'namche', 'in', 'the', 'himalaya', '3400', 'meters', 'oneverest', 'bookofsamuel', 'photo']
# ['expedition', 'leader', 'conradclimber', 'admiring', 'the', 'spirit', 'and', 'effort', 'of', 'a', 'nepali', 'porter', 'oneverest']
# ['a', 'street', 'scene', 'in', 'kathmandu', 'heading', 'into', 'the', 'mountains', 'oneverest']
